# %%
from Bio import SeqIO
import os
from gensim.models import Word2Vec
from nltk.tokenize import word_tokenize
import nltk
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from transformers import BertTokenizer, AutoTokenizer,BertModel, AutoModel 
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
def getFastaData(fasta_path):
    fasta_file = fasta_path

    sequences = []
    for record in SeqIO.parse(fasta_file, "fasta"):
        sequences.append({
            "id": record.id,
            "sequence": str(record.seq)
        })

    result = []

    for sequence in sequences:
        result.append(sequence["sequence"])


    return result

# %%
p = getFastaData(r'./buchong/non-ATP09.fasta')
n = getFastaData(r'./buchong/ATP binding09.fasta')
p_label = [1 for i in range(len(p))]
n_label = [0 for i in range(len(n))]
train_features_first = p + n
trian_labels_first = p_label + n_label

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, matthews_corrcoef, recall_score, precision_score
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression

def comp_result(y_test, y_pred, y_proba):

    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc = roc_auc_score(y_test, y_proba)
    mcc = matthews_corrcoef(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)

    print(f"Accuracy: {accuracy:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"MCC: {mcc:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"Precision: {precision:.4f}")
    
    return accuracy,f1,auc,mcc,recall,precision

# %%
class myModel(torch.nn.Module):
    def __init__(self,esm2):
        super(myModel,self).__init__()
        self.esm2 = esm2
        self.fc1 = torch.nn.Linear(632,32)
        self.fc2 = torch.nn.Linear(32,8)
        self.fc3 = torch.nn.Linear(8,1)
        
        self.conv1 = nn.Conv1d(1, 8, kernel_size=3)
        self.conv2 = nn.Conv1d(8, 2, kernel_size=3)
        self.sigmoid = nn.Sigmoid()
        self.relu = nn.ReLU()  
        self.dropout1 = nn.Dropout(p=0.1)
        self.dropout2 = nn.Dropout(p=0.3)
    def forward(self,x):
        outputs_ = self.esm2(**inputs)

        x = outputs_.last_hidden_state[:, 0, :]
        
        x = x.unsqueeze(1)
        
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = x.view(1, -1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu(x)
        x = self.dropout1(x)
        x = self.fc3(x)
        x = self.sigmoid(x)
        return x

# %%
from sklearn.model_selection import KFold
import numpy as np
import copy as cp
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import joblib
batch_size = 1  

kf = KFold(n_splits=5, shuffle=True, random_state=42)
kf_in = 0
feature = np.array(train_features_first)
label = np.array(trian_labels_first)

for train_index, test_index in kf.split(feature):
    
    best_accuracy_val = 0

    save_model = None
    best_accuracy = 0
    best_f1 = 0
    best_auc = 0
    best_mcc = 0
    best_recall = 0
    best_precision = 0
    kf_in += 1

    print('kf',kf_in)
    train_features, test_features = list(feature[train_index]), list(feature[test_index])
    train_labels, test_labels = list(label[train_index]), list(label[test_index])

    device = torch.device("cuda:3" if torch.cuda.is_available() else "cpu")

    cache_directory = r"/home/hqzhang/neuropeptide prediction/model"

    tokenizer_ = AutoTokenizer.from_pretrained("facebook/esm2_t6_8M_UR50D", cache_dir=cache_directory)
    esm2 = AutoModel.from_pretrained("facebook/esm2_t6_8M_UR50D", cache_dir=cache_directory)
    del esm2.encoder.layer[4:]
    model = myModel(esm2)
    model = model.to(device)

    criterion = nn.BCELoss()
    optimizer = optim.SGD(model.parameters(), lr=0.003)


    
    data_loader = DataLoader(list(zip(train_features, train_labels)), batch_size=batch_size, shuffle=True)

    test_data_loader = DataLoader(list(zip(test_features, test_labels)), batch_size=batch_size, shuffle=False)

    num_epochs = 50
    for epoch in range(num_epochs):
        total_loss = 0
        for batch_input, batch_labels in data_loader:

            inputs = tokenizer_(batch_input, return_tensors='pt', padding=True, truncation=True)
            inputs = inputs.to(device)

            outputs = model(inputs)
            outputs = outputs.view(-1)
            loss = criterion(outputs.to('cpu'), batch_labels.to(torch.float32))

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        model.eval() 

        test_loss = 0
        correct_predictions = 0
        
        
        test_labels_com = []
        predict_labels_com = []
        test_outputs_com = []
        
        
        with torch.no_grad():
            for test_batch_input, test_batch_labels in test_data_loader:
                
                
                inputs = tokenizer_(test_batch_input, return_tensors='pt', padding=True, truncation=True)
                inputs = inputs.to(device)

                test_outputs = model(inputs)
                test_outputs = test_outputs.view(-1)
                test_loss += criterion(test_outputs.to('cpu'), test_batch_labels.to(torch.float32)).item()
                predictions = (test_outputs > 0.5).float() 
                correct_predictions += (predictions.to('cpu') == test_batch_labels).sum().item()
                
                predict_labels_com.extend(predictions.tolist())
                test_labels_com.extend(test_batch_labels.tolist())
                test_outputs_com.extend(test_outputs.tolist())
        
        average_test_loss = test_loss / len(test_data_loader)
        accuracy = correct_predictions / len(test_features)
        
        model.train()
        
        predict_labels_com = np.array(predict_labels_com)
        test_labels_com = np.array(test_labels_com)
        test_outputs_com = np.array(test_outputs_com)

        temp_accuracy_test,temp_f1,temp_auc,temp_mcc,temp_recall,temp_precision = comp_result(test_labels_com,predict_labels_com,test_outputs_com)
        if temp_accuracy_test > best_accuracy:
            best_accuracy = temp_accuracy_test
            best_f1 = temp_f1
            best_auc = temp_auc
            best_mcc = temp_mcc
            best_recall = temp_recall
            best_precision = temp_precision
            save_model = cp.deepcopy(model)
        average_train_loss = total_loss / len(data_loader)
        print('Epoch [{}/{}], Train Loss: {:.4f}, Test Loss: {:.4f}, Accuracy: {:.2f}%'.format(
            epoch + 1, num_epochs, average_train_loss, average_test_loss, accuracy * 100))


    torch.save(save_model, r'./model result/self_20260711model_09_%d.pth' % kf_in)
    print('=====================================')
    print('kf',kf_in,"best result:")
    print(best_accuracy)
    print(best_f1)
    print(best_auc)
    print(best_mcc)
    print(best_recall)
    print(best_precision)
    print('=====================================')
# Out:
# kf 1
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.5067
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.5256
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [1/50], Train Loss: 0.6936, Test Loss: 0.6936, Accuracy: 48.09%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.5833
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.6233
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [2/50], Train Loss: 0.6936, Test Loss: 0.6938, Accuracy: 48.09%
# ================测试集=======================
# Accuracy: 0.5000
# F1 Score: 0.6667
# AUC: 0.6175
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.5000
# ================验证集=======================
# Accuracy: 0.5191
# F1 Score: 0.6834
# AUC: 0.6323
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.5191
# Epoch [3/50], Train Loss: 0.6932, Test Loss: 0.6927, Accuracy: 51.91%
# ================测试集=======================
# Accuracy: 0.5000
# F1 Score: 0.6667
# AUC: 0.6527
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.5000
# ================验证集=======================
# Accuracy: 0.5191
# F1 Score: 0.6834
# AUC: 0.6776
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.5191
# Epoch [4/50], Train Loss: 0.6934, Test Loss: 0.6929, Accuracy: 51.91%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.6836
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.7206
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [5/50], Train Loss: 0.6934, Test Loss: 0.6931, Accuracy: 48.09%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.7074
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.7497
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [6/50], Train Loss: 0.6934, Test Loss: 0.6931, Accuracy: 48.09%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.7272
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.7754
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [7/50], Train Loss: 0.6931, Test Loss: 0.6937, Accuracy: 48.09%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.7424
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.7922
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [8/50], Train Loss: 0.6930, Test Loss: 0.6927, Accuracy: 48.09%
# ================测试集=======================
# Accuracy: 0.5466
# F1 Score: 0.1705
# AUC: 0.7568
# MCC: 0.2211
# Recall: 0.0932
# Precision: 1.0000
# ================验证集=======================
# Accuracy: 0.5303
# F1 Score: 0.1804
# AUC: 0.8116
# MCC: 0.2099
# Recall: 0.0996
# Precision: 0.9583
# Epoch [9/50], Train Loss: 0.6931, Test Loss: 0.6924, Accuracy: 53.03%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.7703
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.8295
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [10/50], Train Loss: 0.6925, Test Loss: 0.6924, Accuracy: 48.09%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.7880
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.8469
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [11/50], Train Loss: 0.6922, Test Loss: 0.6914, Accuracy: 48.09%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.8191
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4809
# F1 Score: 0.0000
# AUC: 0.8663
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [12/50], Train Loss: 0.6906, Test Loss: 0.6883, Accuracy: 48.09%
# ================测试集=======================
# Accuracy: 0.7742
# F1 Score: 0.7842
# AUC: 0.8537
# MCC: 0.5508
# Recall: 0.8208
# Precision: 0.7508
# ================验证集=======================
# Accuracy: 0.8315
# F1 Score: 0.8421
# AUC: 0.8808
# MCC: 0.6628
# Recall: 0.8658
# Precision: 0.8197
# Epoch [13/50], Train Loss: 0.6838, Test Loss: 0.6683, Accuracy: 83.15%
# ================测试集=======================
# Accuracy: 0.8226
# F1 Score: 0.8242
# AUC: 0.8873
# MCC: 0.6453
# Recall: 0.8315
# Precision: 0.8169
# ================验证集=======================
# Accuracy: 0.8494
# F1 Score: 0.8607
# AUC: 0.9160
# MCC: 0.7000
# Recall: 0.8961
# Precision: 0.8280
# Epoch [14/50], Train Loss: 0.6143, Test Loss: 0.4686, Accuracy: 84.94%
# ================测试集=======================
# Accuracy: 0.8226
# F1 Score: 0.7862
# AUC: 0.9270
# MCC: 0.6862
# Recall: 0.6523
# Precision: 0.9891
# ================验证集=======================
# Accuracy: 0.8382
# F1 Score: 0.8173
# AUC: 0.9229
# MCC: 0.7131
# Recall: 0.6970
# Precision: 0.9877
# Epoch [15/50], Train Loss: 0.5182, Test Loss: 0.3892, Accuracy: 83.82%
# ================测试集=======================
# Accuracy: 0.8333
# F1 Score: 0.8383
# AUC: 0.9173
# MCC: 0.6679
# Recall: 0.8638
# Precision: 0.8142
# ================验证集=======================
# Accuracy: 0.8449
# F1 Score: 0.8583
# AUC: 0.9312
# MCC: 0.6925
# Recall: 0.9048
# Precision: 0.8164
# Epoch [16/50], Train Loss: 0.4796, Test Loss: 0.3530, Accuracy: 84.49%
# ================测试集=======================
# Accuracy: 0.8280
# F1 Score: 0.8216
# AUC: 0.9052
# MCC: 0.6576
# Recall: 0.7921
# Precision: 0.8533
# ================验证集=======================
# Accuracy: 0.8292
# F1 Score: 0.8319
# AUC: 0.9058
# MCC: 0.6592
# Recall: 0.8139
# Precision: 0.8507
# Epoch [17/50], Train Loss: 0.4131, Test Loss: 0.3823, Accuracy: 82.92%
# ================测试集=======================
# Accuracy: 0.8602
# F1 Score: 0.8440
# AUC: 0.9292
# MCC: 0.7365
# Recall: 0.7563
# Precision: 0.9548
# ================验证集=======================
# Accuracy: 0.8472
# F1 Score: 0.8350
# AUC: 0.9341
# MCC: 0.7146
# Recall: 0.7446
# Precision: 0.9503
# Epoch [18/50], Train Loss: 0.4523, Test Loss: 0.3309, Accuracy: 84.72%
# ================测试集=======================
# Accuracy: 0.9068
# F1 Score: 0.9019
# AUC: 0.9597
# MCC: 0.8177
# Recall: 0.8566
# Precision: 0.9522
# ================验证集=======================
# Accuracy: 0.8854
# F1 Score: 0.8844
# AUC: 0.9516
# MCC: 0.7747
# Recall: 0.8442
# Precision: 0.9286
# Epoch [19/50], Train Loss: 0.3850, Test Loss: 0.2645, Accuracy: 88.54%
# ================测试集=======================
# Accuracy: 0.8853
# F1 Score: 0.8750
# AUC: 0.9595
# MCC: 0.7813
# Recall: 0.8029
# Precision: 0.9614
# ================验证集=======================
# Accuracy: 0.8764
# F1 Score: 0.8718
# AUC: 0.9511
# MCC: 0.7622
# Recall: 0.8095
# Precision: 0.9444
# Epoch [20/50], Train Loss: 0.3268, Test Loss: 0.2911, Accuracy: 87.64%
# ================测试集=======================
# Accuracy: 0.9158
# F1 Score: 0.9134
# AUC: 0.9621
# MCC: 0.8327
# Recall: 0.8889
# Precision: 0.9394
# ================验证集=======================
# Accuracy: 0.9056
# F1 Score: 0.9095
# AUC: 0.9571
# MCC: 0.8109
# Recall: 0.9134
# Precision: 0.9056
# Epoch [21/50], Train Loss: 0.3003, Test Loss: 0.2524, Accuracy: 90.56%
# ================测试集=======================
# Accuracy: 0.8996
# F1 Score: 0.8931
# AUC: 0.9571
# MCC: 0.8053
# Recall: 0.8387
# Precision: 0.9551
# ================验证集=======================
# Accuracy: 0.8607
# F1 Score: 0.8584
# AUC: 0.9346
# MCC: 0.7263
# Recall: 0.8139
# Precision: 0.9082
# Epoch [22/50], Train Loss: 0.2546, Test Loss: 0.3493, Accuracy: 86.07%
# ================测试集=======================
# Accuracy: 0.7043
# F1 Score: 0.6154
# AUC: 0.8445
# MCC: 0.4608
# Recall: 0.4731
# Precision: 0.8800
# ================验证集=======================
# Accuracy: 0.7191
# F1 Score: 0.6479
# AUC: 0.8569
# MCC: 0.5079
# Recall: 0.4978
# Precision: 0.9274
# Epoch [23/50], Train Loss: 0.2736, Test Loss: 0.5709, Accuracy: 71.91%
# ================测试集=======================
# Accuracy: 0.8978
# F1 Score: 0.8922
# AUC: 0.9579
# MCC: 0.8000
# Recall: 0.8459
# Precision: 0.9440
# ================验证集=======================
# Accuracy: 0.9146
# F1 Score: 0.9152
# AUC: 0.9618
# MCC: 0.8310
# Recall: 0.8874
# Precision: 0.9447
# Epoch [24/50], Train Loss: 0.2636, Test Loss: 0.2292, Accuracy: 91.46%
# ================测试集=======================
# Accuracy: 0.9122
# F1 Score: 0.9081
# AUC: 0.9605
# MCC: 0.8277
# Recall: 0.8674
# Precision: 0.9528
# ================验证集=======================
# Accuracy: 0.8876
# F1 Score: 0.8869
# AUC: 0.9513
# MCC: 0.7789
# Recall: 0.8485
# Precision: 0.9289
# Epoch [25/50], Train Loss: 0.1758, Test Loss: 0.3109, Accuracy: 88.76%
# ================测试集=======================
# Accuracy: 0.9068
# F1 Score: 0.8988
# AUC: 0.9592
# MCC: 0.8239
# Recall: 0.8280
# Precision: 0.9830
# ================验证集=======================
# Accuracy: 0.8876
# F1 Score: 0.8837
# AUC: 0.9596
# MCC: 0.7843
# Recall: 0.8225
# Precision: 0.9548
# Epoch [26/50], Train Loss: 0.1700, Test Loss: 0.2929, Accuracy: 88.76%
# ================测试集=======================
# Accuracy: 0.8871
# F1 Score: 0.8881
# AUC: 0.9525
# MCC: 0.7743
# Recall: 0.8961
# Precision: 0.8803
# ================验证集=======================
# Accuracy: 0.8719
# F1 Score: 0.8785
# AUC: 0.9472
# MCC: 0.7435
# Recall: 0.8918
# Precision: 0.8655
# Epoch [27/50], Train Loss: 0.2187, Test Loss: 0.3007, Accuracy: 87.19%
# ================测试集=======================
# Accuracy: 0.9050
# F1 Score: 0.9055
# AUC: 0.9587
# MCC: 0.8101
# Recall: 0.9104
# Precision: 0.9007
# ================验证集=======================
# Accuracy: 0.8944
# F1 Score: 0.9006
# AUC: 0.9674
# MCC: 0.7890
# Recall: 0.9221
# Precision: 0.8802
# Epoch [28/50], Train Loss: 0.1579, Test Loss: 0.2319, Accuracy: 89.44%
# ================测试集=======================
# Accuracy: 0.8907
# F1 Score: 0.8881
# AUC: 0.9480
# MCC: 0.7822
# Recall: 0.8674
# Precision: 0.9098
# ================验证集=======================
# Accuracy: 0.8674
# F1 Score: 0.8709
# AUC: 0.9537
# MCC: 0.7349
# Recall: 0.8615
# Precision: 0.8805
# Epoch [29/50], Train Loss: 0.0971, Test Loss: 0.3384, Accuracy: 86.74%
# ================测试集=======================
# Accuracy: 0.9050
# F1 Score: 0.9024
# AUC: 0.9602
# MCC: 0.8112
# Recall: 0.8781
# Precision: 0.9280
# ================验证集=======================
# Accuracy: 0.8899
# F1 Score: 0.8914
# AUC: 0.9601
# MCC: 0.7808
# Recall: 0.8701
# Precision: 0.9136
# Epoch [30/50], Train Loss: 0.1271, Test Loss: 0.3213, Accuracy: 88.99%
# ================测试集=======================
# Accuracy: 0.9140
# F1 Score: 0.9124
# AUC: 0.9639
# MCC: 0.8285
# Recall: 0.8961
# Precision: 0.9294
# ================验证集=======================
# Accuracy: 0.9034
# F1 Score: 0.9055
# AUC: 0.9603
# MCC: 0.8071
# Recall: 0.8918
# Precision: 0.9196
# Epoch [31/50], Train Loss: 0.0930, Test Loss: 0.2940, Accuracy: 90.34%
# ================测试集=======================
# Accuracy: 0.9158
# F1 Score: 0.9112
# AUC: 0.9665
# MCC: 0.8361
# Recall: 0.8638
# Precision: 0.9640
# ================验证集=======================
# Accuracy: 0.8944
# F1 Score: 0.8939
# AUC: 0.9632
# MCC: 0.7920
# Recall: 0.8571
# Precision: 0.9340
# Epoch [32/50], Train Loss: 0.0937, Test Loss: 0.3618, Accuracy: 89.44%
# ================测试集=======================
# Accuracy: 0.8996
# F1 Score: 0.8989
# AUC: 0.9642
# MCC: 0.7994
# Recall: 0.8925
# Precision: 0.9055
# ================验证集=======================
# Accuracy: 0.9056
# F1 Score: 0.9103
# AUC: 0.9644
# MCC: 0.8111
# Recall: 0.9221
# Precision: 0.8987
# Epoch [33/50], Train Loss: 0.0958, Test Loss: 0.3142, Accuracy: 90.56%
# ================测试集=======================
# Accuracy: 0.9032
# F1 Score: 0.8996
# AUC: 0.9549
# MCC: 0.8085
# Recall: 0.8674
# Precision: 0.9344
# ================验证集=======================
# Accuracy: 0.8899
# F1 Score: 0.8914
# AUC: 0.9587
# MCC: 0.7808
# Recall: 0.8701
# Precision: 0.9136
# Epoch [34/50], Train Loss: 0.0911, Test Loss: 0.3605, Accuracy: 88.99%
# ================测试集=======================
# Accuracy: 0.9104
# F1 Score: 0.9088
# AUC: 0.9553
# MCC: 0.8213
# Recall: 0.8925
# Precision: 0.9257
# ================验证集=======================
# Accuracy: 0.8809
# F1 Score: 0.8855
# AUC: 0.9583
# MCC: 0.7614
# Recall: 0.8874
# Precision: 0.8836
# Epoch [35/50], Train Loss: 0.0563, Test Loss: 0.3755, Accuracy: 88.09%
# ================测试集=======================
# Accuracy: 0.8871
# F1 Score: 0.8835
# AUC: 0.9491
# MCC: 0.7756
# Recall: 0.8566
# Precision: 0.9122
# ================验证集=======================
# Accuracy: 0.8854
# F1 Score: 0.8884
# AUC: 0.9531
# MCC: 0.7708
# Recall: 0.8788
# Precision: 0.8982
# Epoch [36/50], Train Loss: 0.0504, Test Loss: 0.3840, Accuracy: 88.54%
# ================测试集=======================
# Accuracy: 0.9122
# F1 Score: 0.9052
# AUC: 0.9594
# MCC: 0.8334
# Recall: 0.8387
# Precision: 0.9832
# ================验证集=======================
# Accuracy: 0.8966
# F1 Score: 0.8935
# AUC: 0.9675
# MCC: 0.8013
# Recall: 0.8355
# Precision: 0.9602
# Epoch [37/50], Train Loss: 0.0783, Test Loss: 0.3868, Accuracy: 89.66%
# ================测试集=======================
# Accuracy: 0.9158
# F1 Score: 0.9141
# AUC: 0.9623
# MCC: 0.8322
# Recall: 0.8961
# Precision: 0.9328
# ================验证集=======================
# Accuracy: 0.9056
# F1 Score: 0.9075
# AUC: 0.9659
# MCC: 0.8117
# Recall: 0.8918
# Precision: 0.9238
# Epoch [38/50], Train Loss: 0.0695, Test Loss: 0.3212, Accuracy: 90.56%
# ================测试集=======================
# Accuracy: 0.9104
# F1 Score: 0.9074
# AUC: 0.9626
# MCC: 0.8225
# Recall: 0.8781
# Precision: 0.9387
# ================验证集=======================
# Accuracy: 0.9011
# F1 Score: 0.9027
# AUC: 0.9659
# MCC: 0.8031
# Recall: 0.8831
# Precision: 0.9231
# Epoch [39/50], Train Loss: 0.0334, Test Loss: 0.3775, Accuracy: 90.11%
# ================测试集=======================
# Accuracy: 0.9068
# F1 Score: 0.9004
# AUC: 0.9623
# MCC: 0.8205
# Recall: 0.8423
# Precision: 0.9671
# ================验证集=======================
# Accuracy: 0.8831
# F1 Score: 0.8813
# AUC: 0.9539
# MCC: 0.7714
# Recall: 0.8355
# Precision: 0.9324
# Epoch [40/50], Train Loss: 0.0478, Test Loss: 0.4850, Accuracy: 88.31%
# ================测试集=======================
# Accuracy: 0.8495
# F1 Score: 0.8609
# AUC: 0.9551
# MCC: 0.7086
# Recall: 0.9319
# Precision: 0.8000
# ================验证集=======================
# Accuracy: 0.8831
# F1 Score: 0.8952
# AUC: 0.9596
# MCC: 0.7738
# Recall: 0.9610
# Precision: 0.8377
# Epoch [41/50], Train Loss: 0.0112, Test Loss: 0.5994, Accuracy: 88.31%
# ================测试集=======================
# Accuracy: 0.8943
# F1 Score: 0.8836
# AUC: 0.9529
# MCC: 0.8020
# Recall: 0.8029
# Precision: 0.9825
# ================验证集=======================
# Accuracy: 0.8742
# F1 Score: 0.8667
# AUC: 0.9623
# MCC: 0.7633
# Recall: 0.7879
# Precision: 0.9630
# Epoch [42/50], Train Loss: 0.0227, Test Loss: 0.5323, Accuracy: 87.42%
# ================测试集=======================
# Accuracy: 0.9104
# F1 Score: 0.9094
# AUC: 0.9627
# MCC: 0.8210
# Recall: 0.8996
# Precision: 0.9194
# ================验证集=======================
# Accuracy: 0.9213
# F1 Score: 0.9227
# AUC: 0.9645
# MCC: 0.8434
# Recall: 0.9048
# Precision: 0.9414
# Epoch [43/50], Train Loss: 0.0513, Test Loss: 0.2668, Accuracy: 92.13%
# ================测试集=======================
# Accuracy: 0.8889
# F1 Score: 0.8856
# AUC: 0.9480
# MCC: 0.7791
# Recall: 0.8602
# Precision: 0.9125
# ================验证集=======================
# Accuracy: 0.8944
# F1 Score: 0.8967
# AUC: 0.9551
# MCC: 0.7891
# Recall: 0.8831
# Precision: 0.9107
# Epoch [44/50], Train Loss: 0.0527, Test Loss: 0.3369, Accuracy: 89.44%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9162
# AUC: 0.9532
# MCC: 0.8411
# Recall: 0.8817
# Precision: 0.9535
# ================验证集=======================
# Accuracy: 0.9056
# F1 Score: 0.9062
# AUC: 0.9668
# MCC: 0.8130
# Recall: 0.8788
# Precision: 0.9355
# Epoch [45/50], Train Loss: 0.0514, Test Loss: 0.3274, Accuracy: 90.56%
# ================测试集=======================
# Accuracy: 0.8961
# F1 Score: 0.8858
# AUC: 0.9587
# MCC: 0.8051
# Recall: 0.8065
# Precision: 0.9825
# ================验证集=======================
# Accuracy: 0.8831
# F1 Score: 0.8779
# AUC: 0.9640
# MCC: 0.7775
# Recall: 0.8095
# Precision: 0.9590
# Epoch [46/50], Train Loss: 0.0403, Test Loss: 0.5459, Accuracy: 88.31%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9156
# AUC: 0.9578
# MCC: 0.8421
# Recall: 0.8746
# Precision: 0.9606
# ================验证集=======================
# Accuracy: 0.9034
# F1 Score: 0.9042
# AUC: 0.9701
# MCC: 0.8083
# Recall: 0.8788
# Precision: 0.9312
# Epoch [47/50], Train Loss: 0.0027, Test Loss: 0.4837, Accuracy: 90.34%
# ================测试集=======================
# Accuracy: 0.9140
# F1 Score: 0.9080
# AUC: 0.9586
# MCC: 0.8349
# Recall: 0.8495
# Precision: 0.9753
# ================验证集=======================
# Accuracy: 0.8989
# F1 Score: 0.8975
# AUC: 0.9696
# MCC: 0.8025
# Recall: 0.8528
# Precision: 0.9471
# Epoch [48/50], Train Loss: 0.0060, Test Loss: 0.5154, Accuracy: 89.89%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9151
# AUC: 0.9586
# MCC: 0.8365
# Recall: 0.8889
# Precision: 0.9430
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9119
# AUC: 0.9725
# MCC: 0.8207
# Recall: 0.8961
# Precision: 0.9283
# Epoch [49/50], Train Loss: 0.0038, Test Loss: 0.4771, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9158
# F1 Score: 0.9112
# AUC: 0.9607
# MCC: 0.8361
# Recall: 0.8638
# Precision: 0.9640
# ================验证集=======================
# Accuracy: 0.9034
# F1 Score: 0.9034
# AUC: 0.9717
# MCC: 0.8094
# Recall: 0.8701
# Precision: 0.9393
# Epoch [50/50], Train Loss: 0.0041, Test Loss: 0.5111, Accuracy: 90.34%
# =====================================
# kf 1 best result:
# 0.9213483146067416
# 0.9227373068432672
# 0.9645385766881094
# 0.843400263747183
# 0.9047619047619048
# 0.9414414414414415
# =====================================
# kf 2
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ================测试集=======================
# Accuracy: 0.5000
# F1 Score: 0.6667
# AUC: 0.5145
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.5000
# ================验证集=======================
# Accuracy: 0.4944
# F1 Score: 0.6617
# AUC: 0.5731
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.4944
# Epoch [1/50], Train Loss: 0.6979, Test Loss: 0.6947, Accuracy: 49.44%
# ================测试集=======================
# Accuracy: 0.5000
# F1 Score: 0.6667
# AUC: 0.5904
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.5000
# ================验证集=======================
# Accuracy: 0.4944
# F1 Score: 0.6617
# AUC: 0.6447
# MCC: 0.0000
# Recall: 1.0000
# Precision: 0.4944
# Epoch [2/50], Train Loss: 0.6936, Test Loss: 0.6931, Accuracy: 49.44%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.6909
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5056
# F1 Score: 0.0000
# AUC: 0.7108
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [3/50], Train Loss: 0.6933, Test Loss: 0.6928, Accuracy: 50.56%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.7736
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5056
# F1 Score: 0.0000
# AUC: 0.7924
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [4/50], Train Loss: 0.6931, Test Loss: 0.6921, Accuracy: 50.56%
# ================测试集=======================
# Accuracy: 0.6846
# F1 Score: 0.7389
# AUC: 0.7998
# MCC: 0.4059
# Recall: 0.8925
# Precision: 0.6304
# ================验证集=======================
# Accuracy: 0.7124
# F1 Score: 0.7567
# AUC: 0.8191
# MCC: 0.4628
# Recall: 0.9045
# Precision: 0.6503
# Epoch [5/50], Train Loss: 0.6908, Test Loss: 0.6856, Accuracy: 71.24%
# ================测试集=======================
# Accuracy: 0.8423
# F1 Score: 0.8340
# AUC: 0.9031
# MCC: 0.6881
# Recall: 0.7921
# Precision: 0.8805
# ================验证集=======================
# Accuracy: 0.8382
# F1 Score: 0.8286
# AUC: 0.8984
# MCC: 0.6788
# Recall: 0.7909
# Precision: 0.8700
# Epoch [6/50], Train Loss: 0.6339, Test Loss: 0.4549, Accuracy: 83.82%
# ================测试集=======================
# Accuracy: 0.6326
# F1 Score: 0.7172
# AUC: 0.8674
# MCC: 0.3311
# Recall: 0.9319
# Precision: 0.5830
# ================验证集=======================
# Accuracy: 0.6427
# F1 Score: 0.7235
# AUC: 0.8545
# MCC: 0.3636
# Recall: 0.9455
# Precision: 0.5859
# Epoch [7/50], Train Loss: 0.5268, Test Loss: 0.5927, Accuracy: 64.27%
# ================测试集=======================
# Accuracy: 0.7724
# F1 Score: 0.7221
# AUC: 0.8649
# MCC: 0.5844
# Recall: 0.5914
# Precision: 0.9270
# ================验证集=======================
# Accuracy: 0.7685
# F1 Score: 0.7224
# AUC: 0.8565
# MCC: 0.5634
# Recall: 0.6091
# Precision: 0.8874
# Epoch [8/50], Train Loss: 0.5279, Test Loss: 0.4970, Accuracy: 76.85%
# ================测试集=======================
# Accuracy: 0.7706
# F1 Score: 0.7594
# AUC: 0.8601
# MCC: 0.5436
# Recall: 0.7240
# Precision: 0.7984
# ================验证集=======================
# Accuracy: 0.7730
# F1 Score: 0.7710
# AUC: 0.8460
# MCC: 0.5460
# Recall: 0.7727
# Precision: 0.7692
# Epoch [9/50], Train Loss: 0.4552, Test Loss: 0.4919, Accuracy: 77.30%
# ================测试集=======================
# Accuracy: 0.8763
# F1 Score: 0.8681
# AUC: 0.9510
# MCC: 0.7587
# Recall: 0.8136
# Precision: 0.9303
# ================验证集=======================
# Accuracy: 0.8472
# F1 Score: 0.8373
# AUC: 0.9279
# MCC: 0.6974
# Recall: 0.7955
# Precision: 0.8838
# Epoch [10/50], Train Loss: 0.3957, Test Loss: 0.3327, Accuracy: 84.72%
# ================测试集=======================
# Accuracy: 0.6971
# F1 Score: 0.7443
# AUC: 0.8019
# MCC: 0.4242
# Recall: 0.8817
# Precision: 0.6440
# ================验证集=======================
# Accuracy: 0.7169
# F1 Score: 0.7632
# AUC: 0.8073
# MCC: 0.4787
# Recall: 0.9227
# Precision: 0.6506
# Epoch [11/50], Train Loss: 0.3675, Test Loss: 0.5820, Accuracy: 71.69%
# ================测试集=======================
# Accuracy: 0.7957
# F1 Score: 0.8149
# AUC: 0.9239
# MCC: 0.6046
# Recall: 0.8996
# Precision: 0.7448
# ================验证集=======================
# Accuracy: 0.7933
# F1 Score: 0.8153
# AUC: 0.9194
# MCC: 0.6086
# Recall: 0.9227
# Precision: 0.7302
# Epoch [12/50], Train Loss: 0.4053, Test Loss: 0.3952, Accuracy: 79.33%
# ================测试集=======================
# Accuracy: 0.7688
# F1 Score: 0.7152
# AUC: 0.9068
# MCC: 0.5803
# Recall: 0.5806
# Precision: 0.9310
# ================验证集=======================
# Accuracy: 0.7865
# F1 Score: 0.7453
# AUC: 0.8954
# MCC: 0.5996
# Recall: 0.6318
# Precision: 0.9085
# Epoch [13/50], Train Loss: 0.3064, Test Loss: 0.4456, Accuracy: 78.65%
# ================测试集=======================
# Accuracy: 0.8835
# F1 Score: 0.8790
# AUC: 0.9475
# MCC: 0.7692
# Recall: 0.8459
# Precision: 0.9147
# ================验证集=======================
# Accuracy: 0.8584
# F1 Score: 0.8545
# AUC: 0.9227
# MCC: 0.7171
# Recall: 0.8409
# Precision: 0.8685
# Epoch [14/50], Train Loss: 0.2637, Test Loss: 0.3635, Accuracy: 85.84%
# ================测试集=======================
# Accuracy: 0.8907
# F1 Score: 0.8829
# AUC: 0.9624
# MCC: 0.7883
# Recall: 0.8244
# Precision: 0.9504
# ================验证集=======================
# Accuracy: 0.8989
# F1 Score: 0.8889
# AUC: 0.9522
# MCC: 0.8075
# Recall: 0.8182
# Precision: 0.9730
# Epoch [15/50], Train Loss: 0.2393, Test Loss: 0.2774, Accuracy: 89.89%
# ================测试集=======================
# Accuracy: 0.8871
# F1 Score: 0.8752
# AUC: 0.9608
# MCC: 0.7886
# Recall: 0.7921
# Precision: 0.9779
# ================验证集=======================
# Accuracy: 0.8764
# F1 Score: 0.8601
# AUC: 0.9481
# MCC: 0.7696
# Recall: 0.7682
# Precision: 0.9769
# Epoch [16/50], Train Loss: 0.2142, Test Loss: 0.3641, Accuracy: 87.64%
# ================测试集=======================
# Accuracy: 0.8548
# F1 Score: 0.8541
# AUC: 0.9386
# MCC: 0.7097
# Recall: 0.8495
# Precision: 0.8587
# ================验证集=======================
# Accuracy: 0.8449
# F1 Score: 0.8463
# AUC: 0.9362
# MCC: 0.6906
# Recall: 0.8636
# Precision: 0.8297
# Epoch [17/50], Train Loss: 0.1653, Test Loss: 0.3371, Accuracy: 84.49%
# ================测试集=======================
# Accuracy: 0.8799
# F1 Score: 0.8806
# AUC: 0.9516
# MCC: 0.7599
# Recall: 0.8853
# Precision: 0.8759
# ================验证集=======================
# Accuracy: 0.8742
# F1 Score: 0.8756
# AUC: 0.9502
# MCC: 0.7492
# Recall: 0.8955
# Precision: 0.8565
# Epoch [18/50], Train Loss: 0.1406, Test Loss: 0.3073, Accuracy: 87.42%
# ================测试集=======================
# Accuracy: 0.8889
# F1 Score: 0.8789
# AUC: 0.9619
# MCC: 0.7886
# Recall: 0.8065
# Precision: 0.9657
# ================验证集=======================
# Accuracy: 0.8831
# F1 Score: 0.8687
# AUC: 0.9442
# MCC: 0.7812
# Recall: 0.7818
# Precision: 0.9773
# Epoch [19/50], Train Loss: 0.1596, Test Loss: 0.4068, Accuracy: 88.31%
# ================测试集=======================
# Accuracy: 0.9122
# F1 Score: 0.9136
# AUC: 0.9716
# MCC: 0.8248
# Recall: 0.9283
# Precision: 0.8993
# ================验证集=======================
# Accuracy: 0.8764
# F1 Score: 0.8770
# AUC: 0.9443
# MCC: 0.7532
# Recall: 0.8909
# Precision: 0.8634
# Epoch [20/50], Train Loss: 0.0700, Test Loss: 0.3708, Accuracy: 87.64%
# ================测试集=======================
# Accuracy: 0.8978
# F1 Score: 0.8922
# AUC: 0.9616
# MCC: 0.8000
# Recall: 0.8459
# Precision: 0.9440
# ================验证集=======================
# Accuracy: 0.8899
# F1 Score: 0.8814
# AUC: 0.9516
# MCC: 0.7853
# Recall: 0.8273
# Precision: 0.9430
# Epoch [21/50], Train Loss: 0.0593, Test Loss: 0.4500, Accuracy: 88.99%
# ================测试集=======================
# Accuracy: 0.8961
# F1 Score: 0.8876
# AUC: 0.9692
# MCC: 0.8012
# Recall: 0.8208
# Precision: 0.9662
# ================验证集=======================
# Accuracy: 0.8921
# F1 Score: 0.8829
# AUC: 0.9488
# MCC: 0.7912
# Recall: 0.8227
# Precision: 0.9526
# Epoch [22/50], Train Loss: 0.1027, Test Loss: 0.4232, Accuracy: 89.21%
# ================测试集=======================
# Accuracy: 0.8961
# F1 Score: 0.8945
# AUC: 0.9531
# MCC: 0.7924
# Recall: 0.8817
# Precision: 0.9077
# ================验证集=======================
# Accuracy: 0.8764
# F1 Score: 0.8718
# AUC: 0.9477
# MCC: 0.7536
# Recall: 0.8500
# Precision: 0.8947
# Epoch [23/50], Train Loss: 0.1061, Test Loss: 0.2899, Accuracy: 87.64%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9164
# AUC: 0.9724
# MCC: 0.8355
# Recall: 0.9032
# Precision: 0.9299
# ================验证集=======================
# Accuracy: 0.9011
# F1 Score: 0.8947
# AUC: 0.9557
# MCC: 0.8060
# Recall: 0.8500
# Precision: 0.9444
# Epoch [24/50], Train Loss: 0.0583, Test Loss: 0.3573, Accuracy: 90.11%
# ================测试集=======================
# Accuracy: 0.8907
# F1 Score: 0.8802
# AUC: 0.9636
# MCC: 0.7937
# Recall: 0.8029
# Precision: 0.9739
# ================验证集=======================
# Accuracy: 0.8854
# F1 Score: 0.8722
# AUC: 0.9502
# MCC: 0.7838
# Recall: 0.7909
# Precision: 0.9721
# Epoch [25/50], Train Loss: 0.0891, Test Loss: 0.5153, Accuracy: 88.54%
# ================测试集=======================
# Accuracy: 0.9014
# F1 Score: 0.8940
# AUC: 0.9620
# MCC: 0.8108
# Recall: 0.8315
# Precision: 0.9667
# ================验证集=======================
# Accuracy: 0.8697
# F1 Score: 0.8564
# AUC: 0.9451
# MCC: 0.7487
# Recall: 0.7864
# Precision: 0.9402
# Epoch [26/50], Train Loss: 0.1067, Test Loss: 0.5205, Accuracy: 86.97%
# ================测试集=======================
# Accuracy: 0.8961
# F1 Score: 0.8902
# AUC: 0.9569
# MCC: 0.7967
# Recall: 0.8423
# Precision: 0.9438
# ================验证集=======================
# Accuracy: 0.8517
# F1 Score: 0.8451
# AUC: 0.9318
# MCC: 0.7045
# Recall: 0.8182
# Precision: 0.8738
# Epoch [27/50], Train Loss: 0.0621, Test Loss: 0.4342, Accuracy: 85.17%
# ================测试集=======================
# Accuracy: 0.7939
# F1 Score: 0.8244
# AUC: 0.9480
# MCC: 0.6269
# Recall: 0.9677
# Precision: 0.7181
# ================验证集=======================
# Accuracy: 0.7528
# F1 Score: 0.7901
# AUC: 0.9375
# MCC: 0.5478
# Recall: 0.9409
# Precision: 0.6809
# Epoch [28/50], Train Loss: 0.0425, Test Loss: 0.6356, Accuracy: 75.28%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9142
# AUC: 0.9702
# MCC: 0.8377
# Recall: 0.8781
# Precision: 0.9533
# ================验证集=======================
# Accuracy: 0.9034
# F1 Score: 0.8969
# AUC: 0.9433
# MCC: 0.8108
# Recall: 0.8500
# Precision: 0.9492
# Epoch [29/50], Train Loss: 0.0294, Test Loss: 0.6005, Accuracy: 90.34%
# ================测试集=======================
# Accuracy: 0.9247
# F1 Score: 0.9216
# AUC: 0.9693
# MCC: 0.8521
# Recall: 0.8853
# Precision: 0.9611
# ================验证集=======================
# Accuracy: 0.9056
# F1 Score: 0.9005
# AUC: 0.9479
# MCC: 0.8137
# Recall: 0.8636
# Precision: 0.9406
# Epoch [30/50], Train Loss: 0.0242, Test Loss: 0.5172, Accuracy: 90.56%
# ================测试集=======================
# Accuracy: 0.9229
# F1 Score: 0.9187
# AUC: 0.9704
# MCC: 0.8505
# Recall: 0.8710
# Precision: 0.9720
# ================验证集=======================
# Accuracy: 0.9034
# F1 Score: 0.8969
# AUC: 0.9484
# MCC: 0.8108
# Recall: 0.8500
# Precision: 0.9492
# Epoch [31/50], Train Loss: 0.0108, Test Loss: 0.6192, Accuracy: 90.34%
# ================测试集=======================
# Accuracy: 0.9229
# F1 Score: 0.9187
# AUC: 0.9703
# MCC: 0.8505
# Recall: 0.8710
# Precision: 0.9720
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9012
# AUC: 0.9483
# MCC: 0.8207
# Recall: 0.8500
# Precision: 0.9590
# Epoch [32/50], Train Loss: 0.0099, Test Loss: 0.6607, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9229
# F1 Score: 0.9187
# AUC: 0.9699
# MCC: 0.8505
# Recall: 0.8710
# Precision: 0.9720
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9012
# AUC: 0.9482
# MCC: 0.8207
# Recall: 0.8500
# Precision: 0.9590
# Epoch [33/50], Train Loss: 0.0111, Test Loss: 0.7005, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9229
# F1 Score: 0.9187
# AUC: 0.9703
# MCC: 0.8505
# Recall: 0.8710
# Precision: 0.9720
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9012
# AUC: 0.9484
# MCC: 0.8207
# Recall: 0.8500
# Precision: 0.9590
# Epoch [34/50], Train Loss: 0.0109, Test Loss: 0.7327, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9167
# AUC: 0.9701
# MCC: 0.8472
# Recall: 0.8674
# Precision: 0.9719
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9012
# AUC: 0.9483
# MCC: 0.8207
# Recall: 0.8500
# Precision: 0.9590
# Epoch [35/50], Train Loss: 0.0095, Test Loss: 0.7735, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9703
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9012
# AUC: 0.9484
# MCC: 0.8207
# Recall: 0.8500
# Precision: 0.9590
# Epoch [36/50], Train Loss: 0.0097, Test Loss: 0.7922, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9702
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9007
# AUC: 0.9485
# MCC: 0.8215
# Recall: 0.8455
# Precision: 0.9637
# Epoch [37/50], Train Loss: 0.0081, Test Loss: 0.8179, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9167
# AUC: 0.9702
# MCC: 0.8472
# Recall: 0.8674
# Precision: 0.9719
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9007
# AUC: 0.9483
# MCC: 0.8215
# Recall: 0.8455
# Precision: 0.9637
# Epoch [38/50], Train Loss: 0.0080, Test Loss: 0.8230, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9167
# AUC: 0.9702
# MCC: 0.8472
# Recall: 0.8674
# Precision: 0.9719
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9007
# AUC: 0.9483
# MCC: 0.8215
# Recall: 0.8455
# Precision: 0.9637
# Epoch [39/50], Train Loss: 0.0073, Test Loss: 0.8398, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9167
# AUC: 0.9700
# MCC: 0.8472
# Recall: 0.8674
# Precision: 0.9719
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9007
# AUC: 0.9482
# MCC: 0.8215
# Recall: 0.8455
# Precision: 0.9637
# Epoch [40/50], Train Loss: 0.0060, Test Loss: 0.8508, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9247
# F1 Score: 0.9208
# AUC: 0.9701
# MCC: 0.8538
# Recall: 0.8746
# Precision: 0.9721
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9007
# AUC: 0.9483
# MCC: 0.8215
# Recall: 0.8455
# Precision: 0.9637
# Epoch [41/50], Train Loss: 0.0073, Test Loss: 0.8535, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9167
# AUC: 0.9701
# MCC: 0.8472
# Recall: 0.8674
# Precision: 0.9719
# ================验证集=======================
# Accuracy: 0.9079
# F1 Score: 0.9007
# AUC: 0.9484
# MCC: 0.8215
# Recall: 0.8455
# Precision: 0.9637
# Epoch [42/50], Train Loss: 0.0071, Test Loss: 0.8850, Accuracy: 90.79%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9702
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9484
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [43/50], Train Loss: 0.0065, Test Loss: 0.9005, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9702
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9483
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [44/50], Train Loss: 0.0069, Test Loss: 0.9175, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9701
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9483
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [45/50], Train Loss: 0.0071, Test Loss: 0.9256, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9701
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9483
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [46/50], Train Loss: 0.0082, Test Loss: 0.9351, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9701
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9483
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [47/50], Train Loss: 0.0052, Test Loss: 0.9356, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9146
# AUC: 0.9702
# MCC: 0.8439
# Recall: 0.8638
# Precision: 0.9718
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9482
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [48/50], Train Loss: 0.0071, Test Loss: 0.9564, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9125
# AUC: 0.9701
# MCC: 0.8407
# Recall: 0.8602
# Precision: 0.9717
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9481
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [49/50], Train Loss: 0.0082, Test Loss: 0.9883, Accuracy: 91.01%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9125
# AUC: 0.9700
# MCC: 0.8407
# Recall: 0.8602
# Precision: 0.9717
# ================验证集=======================
# Accuracy: 0.9101
# F1 Score: 0.9029
# AUC: 0.9481
# MCC: 0.8265
# Recall: 0.8455
# Precision: 0.9688
# Epoch [50/50], Train Loss: 0.0054, Test Loss: 1.0001, Accuracy: 91.01%
# =====================================
# kf 2 best result:
# 0.9101123595505618
# 0.9029126213592233
# 0.9484444444444444
# 0.8265385791824791
# 0.8454545454545455
# 0.96875
# =====================================
# kf 3
# Some weights of EsmModel were not initialized from the model checkpoint at facebook/esm2_t6_8M_UR50D and are newly initialized: ['esm.pooler.dense.bias', 'esm.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.4800
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4854
# F1 Score: 0.0000
# AUC: 0.4918
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [1/50], Train Loss: 0.6953, Test Loss: 0.6944, Accuracy: 48.54%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.5046
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4854
# F1 Score: 0.0000
# AUC: 0.5159
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [2/50], Train Loss: 0.6937, Test Loss: 0.6934, Accuracy: 48.54%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.6294
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4854
# F1 Score: 0.0000
# AUC: 0.6398
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [3/50], Train Loss: 0.6933, Test Loss: 0.6933, Accuracy: 48.54%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.6631
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4854
# F1 Score: 0.0000
# AUC: 0.6623
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [4/50], Train Loss: 0.6937, Test Loss: 0.6934, Accuracy: 48.54%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.5617
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.4854
# F1 Score: 0.0000
# AUC: 0.5725
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# Epoch [5/50], Train Loss: 0.6932, Test Loss: 0.6941, Accuracy: 48.54%
# ================测试集=======================
# /home/hqzhang/anaconda3/envs/test/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy: 0.5000
# F1 Score: 0.0000
# AUC: 0.5919
# MCC: 0.0000
# Recall: 0.0000
# Precision: 0.0000
# ================验证集=======================
# ...
# Accuracy: 0.6577
# F1 Score: 0.4830
# AUC: 0.8510
# MCC: 0.3752
# Recall: 0.3333
# Precision: 0.8765
# Epoch [4/50], Train Loss: 0.6648, Test Loss: 0.6287, Accuracy: 65.77%
# ================测试集=======================
# Accuracy: 0.7885
# F1 Score: 0.8127
# AUC: 0.9221
# MCC: 0.5973
# Recall: 0.9176
# Precision: 0.7293
# ================验证集=======================
# Accuracy: 0.7252
# F1 Score: 0.7579
# AUC: 0.8921
# MCC: 0.4876
# Recall: 0.8967
# Precision: 0.6564
# Epoch [5/50], Train Loss: 0.4850, Test Loss: 0.5659, Accuracy: 72.52%
# ================测试集=======================
# Accuracy: 0.8602
# F1 Score: 0.8550
# AUC: 0.9274
# MCC: 0.7223
# Recall: 0.8244
# Precision: 0.8880
# ================验证集=======================
# Accuracy: 0.8266
# F1 Score: 0.8213
# AUC: 0.9032
# MCC: 0.6531
# Recall: 0.8310
# Precision: 0.8119
# Epoch [6/50], Train Loss: 0.4737, Test Loss: 0.4103, Accuracy: 82.66%
# ================测试集=======================
# Accuracy: 0.8943
# F1 Score: 0.8854
# AUC: 0.9499
# MCC: 0.7981
# Recall: 0.8172
# Precision: 0.9661
# ================验证集=======================
# Accuracy: 0.8423
# F1 Score: 0.8232
# AUC: 0.9168
# MCC: 0.6888
# Recall: 0.7653
# Precision: 0.8907
# Epoch [7/50], Train Loss: 0.3617, Test Loss: 0.3896, Accuracy: 84.23%
# ================测试集=======================
# Accuracy: 0.8817
# F1 Score: 0.8711
# AUC: 0.9336
# MCC: 0.7740
# Recall: 0.7993
# Precision: 0.9571
# ================验证集=======================
# Accuracy: 0.8356
# F1 Score: 0.8133
# AUC: 0.9008
# MCC: 0.6771
# Recall: 0.7465
# Precision: 0.8933
# Epoch [8/50], Train Loss: 0.3699, Test Loss: 0.4192, Accuracy: 83.56%
# ================测试集=======================
# Accuracy: 0.9032
# F1 Score: 0.8966
# AUC: 0.9458
# MCC: 0.8133
# Recall: 0.8387
# Precision: 0.9630
# ================验证集=======================
# Accuracy: 0.8423
# F1 Score: 0.8267
# AUC: 0.9135
# MCC: 0.6863
# Recall: 0.7840
# Precision: 0.8743
# Epoch [9/50], Train Loss: 0.3195, Test Loss: 0.3864, Accuracy: 84.23%
# ================测试集=======================
# Accuracy: 0.8853
# F1 Score: 0.8881
# AUC: 0.9503
# MCC: 0.7716
# Recall: 0.9104
# Precision: 0.8669
# ================验证集=======================
# Accuracy: 0.8311
# F1 Score: 0.8373
# AUC: 0.9285
# MCC: 0.6721
# Recall: 0.9061
# Precision: 0.7782
# Epoch [10/50], Train Loss: 0.2587, Test Loss: 0.3646, Accuracy: 83.11%
# ================测试集=======================
# Accuracy: 0.8996
# F1 Score: 0.8935
# AUC: 0.9650
# MCC: 0.8046
# Recall: 0.8423
# Precision: 0.9514
# ================验证集=======================
# Accuracy: 0.8581
# F1 Score: 0.8364
# AUC: 0.9317
# MCC: 0.7263
# Recall: 0.7559
# Precision: 0.9360
# Epoch [11/50], Train Loss: 0.2995, Test Loss: 0.3343, Accuracy: 85.81%
# ================测试集=======================
# Accuracy: 0.8620
# F1 Score: 0.8412
# AUC: 0.9597
# MCC: 0.7501
# Recall: 0.7312
# Precision: 0.9903
# ================验证集=======================
# Accuracy: 0.8221
# F1 Score: 0.7824
# AUC: 0.9263
# MCC: 0.6676
# Recall: 0.6667
# Precision: 0.9467
# Epoch [12/50], Train Loss: 0.2253, Test Loss: 0.3976, Accuracy: 82.21%
# ================测试集=======================
# Accuracy: 0.8996
# F1 Score: 0.8919
# AUC: 0.9524
# MCC: 0.8076
# Recall: 0.8280
# Precision: 0.9665
# ================验证集=======================
# Accuracy: 0.8536
# F1 Score: 0.8354
# AUC: 0.9262
# MCC: 0.7121
# Recall: 0.7746
# Precision: 0.9066
# Epoch [13/50], Train Loss: 0.2326, Test Loss: 0.3783, Accuracy: 85.36%
# ================测试集=======================
# Accuracy: 0.9104
# F1 Score: 0.9064
# AUC: 0.9635
# MCC: 0.8238
# Recall: 0.8674
# Precision: 0.9490
# ================验证集=======================
# Accuracy: 0.8491
# F1 Score: 0.8378
# AUC: 0.9200
# MCC: 0.6982
# Recall: 0.8122
# Precision: 0.8650
# Epoch [14/50], Train Loss: 0.2830, Test Loss: 0.4210, Accuracy: 84.91%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9139
# AUC: 0.9591
# MCC: 0.8382
# Recall: 0.8746
# Precision: 0.9569
# ================验证集=======================
# Accuracy: 0.8671
# F1 Score: 0.8550
# AUC: 0.9402
# MCC: 0.7356
# Recall: 0.8169
# Precision: 0.8969
# Epoch [15/50], Train Loss: 0.2397, Test Loss: 0.3569, Accuracy: 86.71%
# ================测试集=======================
# Accuracy: 0.9104
# F1 Score: 0.9053
# AUC: 0.9655
# MCC: 0.8256
# Recall: 0.8566
# Precision: 0.9598
# ================验证集=======================
# Accuracy: 0.8739
# F1 Score: 0.8614
# AUC: 0.9369
# MCC: 0.7500
# Recall: 0.8169
# Precision: 0.9110
# Epoch [16/50], Train Loss: 0.1829, Test Loss: 0.4172, Accuracy: 87.39%
# ================测试集=======================
# Accuracy: 0.8226
# F1 Score: 0.7880
# AUC: 0.9381
# MCC: 0.6825
# Recall: 0.6595
# Precision: 0.9787
# ================验证集=======================
# Accuracy: 0.7973
# F1 Score: 0.7399
# AUC: 0.9163
# MCC: 0.6318
# Recall: 0.6009
# Precision: 0.9624
# Epoch [17/50], Train Loss: 0.1369, Test Loss: 0.4093, Accuracy: 79.73%
# ================测试集=======================
# Accuracy: 0.9176
# F1 Score: 0.9119
# AUC: 0.9655
# MCC: 0.8422
# Recall: 0.8530
# Precision: 0.9794
# ================验证集=======================
# Accuracy: 0.8896
# F1 Score: 0.8772
# AUC: 0.9448
# MCC: 0.7837
# Recall: 0.8216
# Precision: 0.9409
# Epoch [18/50], Train Loss: 0.1382, Test Loss: 0.3396, Accuracy: 88.96%
# ================测试集=======================
# Accuracy: 0.9158
# F1 Score: 0.9150
# AUC: 0.9639
# MCC: 0.8317
# Recall: 0.9068
# Precision: 0.9234
# ================验证集=======================
# Accuracy: 0.8671
# F1 Score: 0.8618
# AUC: 0.9376
# MCC: 0.7339
# Recall: 0.8638
# Precision: 0.8598
# Epoch [19/50], Train Loss: 0.0918, Test Loss: 0.4892, Accuracy: 86.71%
# ================测试集=======================
# Accuracy: 0.9122
# F1 Score: 0.9088
# AUC: 0.9673
# MCC: 0.8267
# Recall: 0.8746
# Precision: 0.9457
# ================验证集=======================
# Accuracy: 0.8739
# F1 Score: 0.8607
# AUC: 0.9424
# MCC: 0.7507
# Recall: 0.8122
# Precision: 0.9153
# Epoch [20/50], Train Loss: 0.1333, Test Loss: 0.4127, Accuracy: 87.39%
# ================测试集=======================
# Accuracy: 0.8978
# F1 Score: 0.8876
# AUC: 0.9687
# MCC: 0.8093
# Recall: 0.8065
# Precision: 0.9868
# ================验证集=======================
# Accuracy: 0.8581
# F1 Score: 0.8389
# AUC: 0.9423
# MCC: 0.7231
# Recall: 0.7700
# Precision: 0.9213
# Epoch [21/50], Train Loss: 0.0839, Test Loss: 0.4091, Accuracy: 85.81%
# ================测试集=======================
# Accuracy: 0.9140
# F1 Score: 0.9127
# AUC: 0.9653
# MCC: 0.8283
# Recall: 0.8996
# Precision: 0.9262
# ================验证集=======================
# Accuracy: 0.8739
# F1 Score: 0.8647
# AUC: 0.9462
# MCC: 0.7479
# Recall: 0.8404
# Precision: 0.8905
# Epoch [22/50], Train Loss: 0.0489, Test Loss: 0.4676, Accuracy: 87.39%
# ================测试集=======================
# Accuracy: 0.9014
# F1 Score: 0.8940
# AUC: 0.9617
# MCC: 0.8108
# Recall: 0.8315
# Precision: 0.9667
# ================验证集=======================
# Accuracy: 0.8649
# F1 Score: 0.8454
# AUC: 0.9389
# MCC: 0.7385
# Recall: 0.7700
# Precision: 0.9371
# Epoch [23/50], Train Loss: 0.0358, Test Loss: 0.5248, Accuracy: 86.49%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9670
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8761
# F1 Score: 0.8628
# AUC: 0.9440
# MCC: 0.7556
# Recall: 0.8122
# Precision: 0.9202
# Epoch [24/50], Train Loss: 0.1122, Test Loss: 0.4710, Accuracy: 87.61%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9157
# AUC: 0.9651
# MCC: 0.8494
# Recall: 0.8566
# Precision: 0.9835
# ================验证集=======================
# Accuracy: 0.8874
# F1 Score: 0.8724
# AUC: 0.9420
# MCC: 0.7824
# Recall: 0.8028
# Precision: 0.9553
# Epoch [25/50], Train Loss: 0.0124, Test Loss: 0.6244, Accuracy: 88.74%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9176
# AUC: 0.9655
# MCC: 0.8454
# Recall: 0.8781
# Precision: 0.9608
# ================验证集=======================
# Accuracy: 0.8874
# F1 Score: 0.8768
# AUC: 0.9448
# MCC: 0.7768
# Recall: 0.8357
# Precision: 0.9223
# Epoch [26/50], Train Loss: 0.0039, Test Loss: 0.6631, Accuracy: 88.74%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9173
# AUC: 0.9665
# MCC: 0.8460
# Recall: 0.8746
# Precision: 0.9644
# ================验证集=======================
# Accuracy: 0.8784
# F1 Score: 0.8663
# AUC: 0.9459
# MCC: 0.7592
# Recall: 0.8216
# Precision: 0.9162
# Epoch [27/50], Train Loss: 0.0065, Test Loss: 0.7358, Accuracy: 87.84%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9662
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8806
# F1 Score: 0.8685
# AUC: 0.9449
# MCC: 0.7640
# Recall: 0.8216
# Precision: 0.9211
# Epoch [28/50], Train Loss: 0.0046, Test Loss: 0.7888, Accuracy: 88.06%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9668
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8806
# F1 Score: 0.8685
# AUC: 0.9449
# MCC: 0.7640
# Recall: 0.8216
# Precision: 0.9211
# Epoch [29/50], Train Loss: 0.0069, Test Loss: 0.8200, Accuracy: 88.06%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9666
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9454
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [30/50], Train Loss: 0.0035, Test Loss: 1.0276, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9669
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8806
# F1 Score: 0.8691
# AUC: 0.9459
# MCC: 0.7634
# Recall: 0.8263
# Precision: 0.9167
# Epoch [31/50], Train Loss: 0.0028, Test Loss: 1.0523, Accuracy: 88.06%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9173
# AUC: 0.9671
# MCC: 0.8460
# Recall: 0.8746
# Precision: 0.9644
# ================验证集=======================
# Accuracy: 0.8806
# F1 Score: 0.8691
# AUC: 0.9450
# MCC: 0.7634
# Recall: 0.8263
# Precision: 0.9167
# Epoch [32/50], Train Loss: 0.0051, Test Loss: 1.2595, Accuracy: 88.06%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9173
# AUC: 0.9662
# MCC: 0.8460
# Recall: 0.8746
# Precision: 0.9644
# ================验证集=======================
# Accuracy: 0.8851
# F1 Score: 0.8747
# AUC: 0.9452
# MCC: 0.7720
# Recall: 0.8357
# Precision: 0.9175
# Epoch [33/50], Train Loss: 0.0030, Test Loss: 1.2768, Accuracy: 88.51%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9173
# AUC: 0.9663
# MCC: 0.8460
# Recall: 0.8746
# Precision: 0.9644
# ================验证集=======================
# Accuracy: 0.8851
# F1 Score: 0.8747
# AUC: 0.9455
# MCC: 0.7720
# Recall: 0.8357
# Precision: 0.9175
# Epoch [34/50], Train Loss: 0.0023, Test Loss: 1.2947, Accuracy: 88.51%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9662
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9454
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [35/50], Train Loss: 0.0033, Test Loss: 1.3209, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9663
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9456
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [36/50], Train Loss: 0.0011, Test Loss: 1.3311, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9664
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8806
# F1 Score: 0.8691
# AUC: 0.9458
# MCC: 0.7634
# Recall: 0.8263
# Precision: 0.9167
# Epoch [37/50], Train Loss: 0.0025, Test Loss: 1.3415, Accuracy: 88.06%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9665
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8874
# F1 Score: 0.8768
# AUC: 0.9459
# MCC: 0.7768
# Recall: 0.8357
# Precision: 0.9223
# Epoch [38/50], Train Loss: 0.0035, Test Loss: 1.3516, Accuracy: 88.74%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9665
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8874
# F1 Score: 0.8768
# AUC: 0.9460
# MCC: 0.7768
# Recall: 0.8357
# Precision: 0.9223
# Epoch [39/50], Train Loss: 0.0034, Test Loss: 1.3625, Accuracy: 88.74%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9666
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9460
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [40/50], Train Loss: 0.0035, Test Loss: 1.3817, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9663
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9457
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [41/50], Train Loss: 0.0024, Test Loss: 1.3948, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9149
# AUC: 0.9663
# MCC: 0.8433
# Recall: 0.8674
# Precision: 0.9680
# ================验证集=======================
# Accuracy: 0.8851
# F1 Score: 0.8734
# AUC: 0.9457
# MCC: 0.7731
# Recall: 0.8263
# Precision: 0.9263
# Epoch [42/50], Train Loss: 0.0030, Test Loss: 1.4061, Accuracy: 88.51%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9664
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8851
# F1 Score: 0.8734
# AUC: 0.9459
# MCC: 0.7731
# Recall: 0.8263
# Precision: 0.9263
# Epoch [43/50], Train Loss: 0.0042, Test Loss: 1.4117, Accuracy: 88.51%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9664
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9460
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [44/50], Train Loss: 0.0026, Test Loss: 1.4198, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9665
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9460
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [45/50], Train Loss: 0.0016, Test Loss: 1.4276, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9665
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9461
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [46/50], Train Loss: 0.0044, Test Loss: 1.4305, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9665
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9460
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [47/50], Train Loss: 0.0010, Test Loss: 1.4387, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9664
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9462
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [48/50], Train Loss: 0.0025, Test Loss: 1.4433, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9211
# F1 Score: 0.9170
# AUC: 0.9665
# MCC: 0.8466
# Recall: 0.8710
# Precision: 0.9681
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9462
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [49/50], Train Loss: 0.0020, Test Loss: 1.4579, Accuracy: 88.29%
# ================测试集=======================
# Accuracy: 0.9194
# F1 Score: 0.9153
# AUC: 0.9666
# MCC: 0.8427
# Recall: 0.8710
# Precision: 0.9643
# ================验证集=======================
# Accuracy: 0.8829
# F1 Score: 0.8713
# AUC: 0.9464
# MCC: 0.7683
# Recall: 0.8263
# Precision: 0.9215
# Epoch [50/50], Train Loss: 0.0019, Test Loss: 1.4616, Accuracy: 88.29%
# =====================================
# kf 5 best result:
# 0.8896396396396397
# 0.8771929824561404
# 0.9447594658862264
# 0.7837140487515738
# 0.8215962441314554
# 0.9408602150537635
# =====================================
